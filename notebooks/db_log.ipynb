# %%
from get_parms import mongo_collection

# %%
for x in mongo_collection().find():
    print(x)
# Out:
# {'_id': ObjectId('64a19ca6ae9a36d31853ad1f'), 'questions': [{'question_text': 'What is the main purpose of The mastery Algorithm?', 'options': ['To generate multiple choice question quizzes', 'To provide factual information', 'To confuse students', 'To improve learning outcomes'], 'correct_option_idx': 3, 'explanation': 'The main purpose of The mastery Algorithm is to improve learning outcomes.'}, {'question_text': 'Which programming language is commonly used for implementing The mastery Algorithm?', 'options': ['Python', 'Java', 'C++', 'JavaScript'], 'correct_option_idx': 0, 'explanation': 'Python is commonly used for implementing The mastery Algorithm.'}, {'question_text': 'What is the maximum character limit for the question text in The mastery Algorithm?', 'options': ['100', '255', '50', '200'], 'correct_option_idx': 1, 'explanation': 'The maximum character limit for the question text in The mastery Algorithm is 255 characters.'}, {'question_text': 'What should the options in the
# ...
