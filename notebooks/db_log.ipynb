# %%
from get_parms import mongo_collection
from collections import defaultdict
import pandas as pd

# %%
data = []
for obj in mongo_collection().find():
    data.append(obj)
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                         _id  \
# 0  64a1c5d8fda740a4402c328c
# 1  64a1d3adfda740a4402c328e
# 2  64a24908fda740a4402c3290
# 3  64a24bbbfda740a4402c3292
# 4  64a2d193fda740a4402c3294
#
#                                            questions  \
# 0  [{'question_text': 'What is an algorithm?', 'o...
# 1  [{'question_text': 'What is the time complexit...
# 2  [{'question_text': 'What is the time complexit...
# 3  [{'question_text': 'What is the time complexit...
# 4  [{'question_text': 'What is the purpose of sys...
#
#                                         prompt                datetime
# 0                    coding algorithm overview 2023-07-02 18:45:44.003
# 1                      binary search algorithm 2023-07-02 19:44:45.264
# 2  Binary search algorithm in machine learning 2023-07-03 04:05:28.411
# 3           Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 4             system design interview question 2023-07-03 13:48:03.067

# %%
df = df.explode(column="questions")

# %%
df.head()
# Out:
#                         _id  \
# 0  64a1c5d8fda740a4402c328c
# 0  64a1c5d8fda740a4402c328c
# 0  64a1c5d8fda740a4402c328c
# 0  64a1c5d8fda740a4402c328c
# 0  64a1c5d8fda740a4402c328c
#
#                                            questions  \
# 0  {'question_text': 'What is an algorithm?', 'op...
# 0  {'question_text': 'What is the time complexity...
# 0  {'question_text': 'Which sorting algorithm has...
# 0  {'question_text': 'What is the purpose of a bi...
# 0  {'question_text': 'Which data structure uses t...
#
#                       prompt                datetime
# 0  coding algorithm overview 2023-07-02 18:45:44.003
# 0  coding algorithm overview 2023-07-02 18:45:44.003
# 0  coding algorithm overview 2023-07-02 18:45:44.003
# 0  coding algorithm overview 2023-07-02 18:45:44.003
# 0  coding algorithm overview 2023-07-02 18:45:44.003

# %%
prompt = df["prompt"].unique().tolist()
print(*prompt, sep="\n")
# Out:
# coding algorithm overview
# binary search algorithm
# Binary search algorithm in machine learning
# Big O and small o notation quizzes
# system design interview question

# %%
df[df["prompt"]=="Big O and small o notation quizzes"]
# Out:
#                         _id  \
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
# 3  64a24bbbfda740a4402c3292
#
#                                            questions  \
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the time complexity...
# 3  {'question_text': 'What is the space complexit...
#
#                                prompt                datetime
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
# 3  Big O and small o notation quizzes 2023-07-03 04:16:59.916
